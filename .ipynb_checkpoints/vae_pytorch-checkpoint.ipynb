# %%
import os
import torch
import numpy as np
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import matplotlib.image as mpimg
from matplotlib import pyplot as plt
from torchvision import transforms
from torchvision.utils import save_image

# %%
image_size = 784
h_dim = 400
z_dim = 20
num_epochs = 30
batch_size = 128
learning_rate = 0.001

# %%
#下载MNIST训练集，这里因已下载，故download=False
# 如果需要下载，设置download=True将自动下载
dataset = torchvision.datasets.MNIST(root='data',
                                    train=True,
                                    transform=transforms.ToTensor(),
                                    download=False)
# 数据加载
data_loader = torch.utils.data.DataLoader(dataset=dataset,
                                         batch_size=batch_size,
                                         shuffle=True)

# %%
#定义vae模型
class VAE(nn.Module):
    def __init__(self, image_size=784, h_dim=400, z_dim=20):
        super(VAE, self).__init__()
        self.fc1 = nn.Linear(image_size, h_dim)
        self.fc2 = nn.Linear(h_dim, z_dim)
        self.fc3 = nn.Linear(h_dim, z_dim)
        self.fc4 = nn.Linear(z_dim,h_dim)
        self.fc5 = nn.Linear(h_dim, image_size)
    
    def encode(self,x):
        h = F.relu(self.fc1(x))
        return self.fc2(h), self.fc3(h)
    
    # 用mu, log_var生成一个潜在空间点z, mu, log_var为两个统计参数，我们假设这个假设能生成图像。
    def reparameterize(self, mu, log_var):
        std = torch.exp(log_var/2)
        eps = torch.randn_like(std)
        return mu + eps * std
    def decode(self, z):
        h = F.relu(self.fc4(z))
        return F.sigmoid(self.fc5(h))
    
    def forward(self, x):
        mu, log_var = self.encode(x)
        z = self.reparameterize(mu, log_var)
        x_reconst = self.decode(z)
        return x_reconst, mu ,log_var

# %%
#在当前目录，创建不存在的目录ave_samples
sample_dir = 'ave_samples'
if not os.path.exists(sample_dir):
    os.makedirs(sample_dir)
# 设置PyTorch在哪块GPU上运行，这里假设使用序号为1的这块GPU
# torch.cuda.set_device(1)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = VAE().to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# %%
#开始训练模型
for epoch in range(num_epochs):
    model.train()
    for i,(x,_) in enumerate(data_loader):
        #前向传播
        model.zero_grad()
        x = x.to(device).view(-1,image_size)
        x_reconst, mu, log_var = model(x)
        
        # Compute reconstruction loss and kl divergence
        # 关于参数size_average=False，根据pytorch的官方文档，size_average默认情况下是True，对每个小批次的损失取平均值。 
        # 但是，如果字段size_average设置为False，则每个小批次的损失将被相加。如果参数reduce=False，则忽略
        # class torch.nn.CrossEntropyLoss(weight=None, size_average=True, ignore_index=-100, reduce=True)
        reconst_loss = F.binary_cross_entropy(x_reconst, x, size_average=False)
        kl_div = -0.5 * torch.sum(1 + log_var - mu.pow(2) - log_var.exp())
        
        #反向传播及优化器
        loss = reconst_loss + kl_div
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        if (i+1) % 100 ==0:
            print("Epoch[{}/{}], Step[{}/{}], Reconst Loss: {:.4f}, KL Div: {:.4f}"
                 .format(epoch+1, num_epochs, i+1, len(data_loader), reconst_loss.item(), kl_div.item()))
    
    with torch.no_grad():
        # 保存采样图像，即潜在向量Z通过解码器生成的新图像
        z = torch.randn(batch_size, z_dim).to(device)
        out = model.decode(z).view(-1, 1, 28, 28)
        save_image(out, os.path.join(sample_dir, 'sampled-{}.png'.format(epoch+1)))

        # 保存重构图像，即原图像通过解码器生成的图像
        out, _, _ = model(x)
        x_concat = torch.cat([x.view(-1, 1, 28, 28), out.view(-1, 1, 28, 28)], dim=3)
        save_image(x_concat, os.path.join(sample_dir, 'reconst-{}.png'.format(epoch+1)))
# Out:
# Epoch[1/30], Step[100/469], Reconst Loss: 22045.3125, KL Div: 1460.5200
# Epoch[1/30], Step[200/469], Reconst Loss: 18135.7578, KL Div: 1989.3989
# Epoch[1/30], Step[300/469], Reconst Loss: 15112.2578, KL Div: 2165.5640
# Epoch[1/30], Step[400/469], Reconst Loss: 14248.2773, KL Div: 2356.8047
# Epoch[2/30], Step[100/469], Reconst Loss: 13111.5488, KL Div: 2789.2412
# Epoch[2/30], Step[200/469], Reconst Loss: 12459.1133, KL Div: 2712.2402
# Epoch[2/30], Step[300/469], Reconst Loss: 12236.4824, KL Div: 2943.2754
# Epoch[2/30], Step[400/469], Reconst Loss: 11812.9639, KL Div: 2964.2388
# Epoch[3/30], Step[100/469], Reconst Loss: 11534.7500, KL Div: 3072.5728
# Epoch[3/30], Step[200/469], Reconst Loss: 11641.8281, KL Div: 3084.6816
# Epoch[3/30], Step[300/469], Reconst Loss: 11415.1367, KL Div: 3085.5732
# Epoch[3/30], Step[400/469], Reconst Loss: 10899.7480, KL Div: 3142.2378
# Epoch[4/30], Step[100/469], Reconst Loss: 11235.2266, KL Div: 3106.0496
# Epoch[4/30], Step[200/469], Reconst Loss: 11117.9404, KL Div: 3080.7456
# Epoch[4/30], Step[300/469], Reconst Loss: 10809.9736, KL Div: 3072.9031
# Epoch[4/30], Step[400/469], Reconst Loss: 10810.1875, KL Div: 3248.8765
# Epoch[5/30], Step[100/469], Reconst Loss: 11127.9678, KL Div: 3161.3474
# Epoch[5/30], Step[200/469], Reconst Loss: 10420.4580, KL Div: 3112.5596
# Epoch[5/30], Step[300/469], Reconst Loss: 10279.8760, KL Div: 3098.8887
# Epoch[5/30], Step[400/469], Reconst Loss: 10528.1348, KL Div: 3185.5928
# Epoch[6/30], Step[100/469], Reconst Loss: 10468.3438, KL Div: 3164.0095
# Epoch[6/30], Step[200/469], Reconst Loss: 10093.0137, KL Div: 3186.5449
# Epoch[6/30], Step[300/469], Reconst Loss: 10854.2773, KL Div: 3257.4668
# Epoch[6/30], Step[400/469], Reconst Loss: 10484.1133, KL Div: 3147.4988
# Epoch[7/30], Step[100/469], Reconst Loss: 10971.2852, KL Div: 3180.3794
# Epoch[7/30], Step[200/469], Reconst Loss: 10690.0020, KL Div: 3223.4800
# Epoch[7/30], Step[300/469], Reconst Loss: 10681.5156, KL Div: 3268.8208
# Epoch[7/30], Step[400/469], Reconst Loss: 10608.9355, KL Div: 3212.0037
# Epoch[8/30], Step[100/469], Reconst Loss: 10494.5977, KL Div: 3248.1917
# Epoch[8/30], Step[200/469], Reconst Loss: 10839.3809, KL Div: 3229.0559
# Epoch[8/30], Step[300/469], Reconst Loss: 10637.1914, KL Div: 3116.9097
# Epoch[8/30], Step[400/469], Reconst Loss: 10643.4736, KL Div: 3357.3525
# Epoch[9/30], Step[100/469], Reconst Loss: 10429.8926, KL Div: 3245.0981
# Epoch[9/30], Step[200/469], Reconst Loss: 10657.0801, KL Div: 3230.8462
# Epoch[9/30], Step[300/469], Reconst Loss: 10887.4629, KL Div: 3200.5166
# Epoch[9/30], Step[400/469], Reconst Loss: 10319.6201, KL Div: 3202.3267
# Epoch[10/30], Step[100/469], Reconst Loss: 9709.0439, KL Div: 3119.0486
# Epoch[10/30], Step[200/469], Reconst Loss: 10368.5332, KL Div: 3187.0762
# Epoch[10/30], Step[300/469], Reconst Loss: 10296.2832, KL Div: 3212.3345
# Epoch[10/30], Step[400/469], Reconst Loss: 10233.5801, KL Div: 3275.3594
# Epoch[11/30], Step[100/469], Reconst Loss: 10226.1602, KL Div: 3252.5852
# Epoch[11/30], Step[200/469], Reconst Loss: 10491.1504, KL Div: 3250.1384
# Epoch[11/30], Step[300/469], Reconst Loss: 10262.2812, KL Div: 3212.9526
# Epoch[11/30], Step[400/469], Reconst Loss: 10287.4717, KL Div: 3264.2031
# Epoch[12/30], Step[100/469], Reconst Loss: 10130.6416, KL Div: 3174.8696
# Epoch[12/30], Step[200/469], Reconst Loss: 10379.1523, KL Div: 3269.4741
# Epoch[12/30], Step[300/469], Reconst Loss: 9844.7061, KL Div: 3179.8643
# Epoch[12/30], Step[400/469], Reconst Loss: 10502.9355, KL Div: 3259.5771
# Epoch[13/30], Step[100/469], Reconst Loss: 10442.3750, KL Div: 3320.6387
# Epoch[13/30], Step[200/469], Reconst Loss: 10050.2051, KL Div: 3179.6880
# Epoch[13/30], Step[300/469], Reconst Loss: 9831.9688, KL Div: 3242.3884
# Epoch[13/30], Step[400/469], Reconst Loss: 10501.4600, KL Div: 3302.3999
# Epoch[14/30], Step[100/469], Reconst Loss: 10368.2715, KL Div: 3181.0713
# Epoch[14/30], Step[200/469], Reconst Loss: 10169.6865, KL Div: 3245.8394
# Epoch[14/30], Step[300/469], Reconst Loss: 10313.2891, KL Div: 3324.7466
# Epoch[14/30], Step[400/469], Reconst Loss: 10605.4785, KL Div: 3251.9238
# Epoch[15/30], Step[100/469], Reconst Loss: 10291.2002, KL Div: 3253.6887
# Epoch[15/30], Step[200/469], Reconst Loss: 10074.4961, KL Div: 3204.2646
# Epoch[15/30], Step[300/469], Reconst Loss: 9846.7832, KL Div: 3226.8655
# Epoch[15/30], Step[400/469], Reconst Loss: 10200.0449, KL Div: 3240.6973
# Epoch[16/30], Step[100/469], Reconst Loss: 9979.4355, KL Div: 3205.8188
# Epoch[16/30], Step[200/469], Reconst Loss: 10335.2656, KL Div: 3265.3809
# Epoch[16/30], Step[300/469], Reconst Loss: 9985.3789, KL Div: 3237.2324
# Epoch[16/30], Step[400/469], Reconst Loss: 9825.2695, KL Div: 3234.6182
# Epoch[17/30], Step[100/469], Reconst Loss: 10378.7148, KL Div: 3238.2852
# Epoch[17/30], Step[200/469], Reconst Loss: 10150.5244, KL Div: 3096.7278
# Epoch[17/30], Step[300/469], Reconst Loss: 9877.8867, KL Div: 3183.1577
# Epoch[17/30], Step[400/469], Reconst Loss: 10460.4209, KL Div: 3309.7920
# Epoch[18/30], Step[100/469], Reconst Loss: 9982.3047, KL Div: 3286.7847
# Epoch[18/30], Step[200/469], Reconst Loss: 10428.2500, KL Div: 3288.9229
# Epoch[18/30], Step[300/469], Reconst Loss: 9849.3828, KL Div: 3176.3669
# Epoch[18/30], Step[400/469], Reconst Loss: 10678.5020, KL Div: 3286.5752
# Epoch[19/30], Step[100/469], Reconst Loss: 10059.0010, KL Div: 3197.8525
# Epoch[19/30], Step[200/469], Reconst Loss: 10093.0283, KL Div: 3268.7314
# Epoch[19/30], Step[300/469], Reconst Loss: 9940.2168, KL Div: 3222.1963
# Epoch[19/30], Step[400/469], Reconst Loss: 10366.7686, KL Div: 3353.2393
# Epoch[20/30], Step[100/469], Reconst Loss: 10145.5293, KL Div: 3300.2046
# Epoch[20/30], Step[200/469], Reconst Loss: 10046.7188, KL Div: 3294.3679
# Epoch[20/30], Step[300/469], Reconst Loss: 10028.1035, KL Div: 3300.3296
# Epoch[20/30], Step[400/469], Reconst Loss: 10139.1279, KL Div: 3318.8298
# Epoch[21/30], Step[100/469], Reconst Loss: 9887.7441, KL Div: 3255.6816
# Epoch[21/30], Step[200/469], Reconst Loss: 10219.4736, KL Div: 3328.0972
# Epoch[21/30], Step[300/469], Reconst Loss: 9837.4531, KL Div: 3165.6660
# Epoch[21/30], Step[400/469], Reconst Loss: 10065.1133, KL Div: 3127.6450
# Epoch[22/30], Step[100/469], Reconst Loss: 10188.0391, KL Div: 3247.4297
# Epoch[22/30], Step[200/469], Reconst Loss: 9856.1816, KL Div: 3224.9626
# Epoch[22/30], Step[300/469], Reconst Loss: 10035.7539, KL Div: 3225.4006
# Epoch[22/30], Step[400/469], Reconst Loss: 9990.3223, KL Div: 3280.1704
# Epoch[23/30], Step[100/469], Reconst Loss: 9999.5635, KL Div: 3285.0430
# Epoch[23/30], Step[200/469], Reconst Loss: 9797.2930, KL Div: 3202.0781
# Epoch[23/30], Step[300/469], Reconst Loss: 9733.6660, KL Div: 3269.5254
# Epoch[23/30], Step[400/469], Reconst Loss: 9696.4961, KL Div: 3074.9106
# Epoch[24/30], Step[100/469], Reconst Loss: 9909.4932, KL Div: 3339.8496
# Epoch[24/30], Step[200/469], Reconst Loss: 10150.3662, KL Div: 3285.6484
# Epoch[24/30], Step[300/469], Reconst Loss: 9850.8340, KL Div: 3251.0518
# Epoch[24/30], Step[400/469], Reconst Loss: 9438.3770, KL Div: 3221.3467
# Epoch[25/30], Step[100/469], Reconst Loss: 10037.8223, KL Div: 3220.8999
# Epoch[25/30], Step[200/469], Reconst Loss: 10025.0352, KL Div: 3203.4224
# Epoch[25/30], Step[300/469], Reconst Loss: 9852.7012, KL Div: 3226.7400
# Epoch[25/30], Step[400/469], Reconst Loss: 10361.1836, KL Div: 3290.4321
# Epoch[26/30], Step[100/469], Reconst Loss: 10008.7910, KL Div: 3243.0513
# Epoch[26/30], Step[200/469], Reconst Loss: 10092.4473, KL Div: 3252.5017
# Epoch[26/30], Step[300/469], Reconst Loss: 9282.0967, KL Div: 3138.3564
# Epoch[26/30], Step[400/469], Reconst Loss: 9643.6279, KL Div: 3273.0911
# Epoch[27/30], Step[100/469], Reconst Loss: 10327.4434, KL Div: 3313.4951
# Epoch[27/30], Step[200/469], Reconst Loss: 9672.2871, KL Div: 3211.4575
# Epoch[27/30], Step[300/469], Reconst Loss: 10055.0918, KL Div: 3240.7588
# Epoch[27/30], Step[400/469], Reconst Loss: 10337.9180, KL Div: 3314.7332
# Epoch[28/30], Step[100/469], Reconst Loss: 9348.2773, KL Div: 3135.2432
# Epoch[28/30], Step[200/469], Reconst Loss: 10002.2998, KL Div: 3317.9717
# Epoch[28/30], Step[300/469], Reconst Loss: 9456.4590, KL Div: 3304.5537
# Epoch[28/30], Step[400/469], Reconst Loss: 9567.5215, KL Div: 3230.6301
# Epoch[29/30], Step[100/469], Reconst Loss: 10012.9023, KL Div: 3326.3794
# Epoch[29/30], Step[200/469], Reconst Loss: 10136.8848, KL Div: 3272.6318
# Epoch[29/30], Step[300/469], Reconst Loss: 10449.1191, KL Div: 3412.3018
# Epoch[29/30], Step[400/469], Reconst Loss: 10143.4131, KL Div: 3291.0251
# Epoch[30/30], Step[100/469], Reconst Loss: 9364.1787, KL Div: 3159.5366
# Epoch[30/30], Step[200/469], Reconst Loss: 9705.1934, KL Div: 3333.7617
# Epoch[30/30], Step[300/469], Reconst Loss: 9626.0479, KL Div: 3282.5342
# Epoch[30/30], Step[400/469], Reconst Loss: 9756.5264, KL Div: 3239.0256

# %%
reconsPath = './ave_samples/reconst-30.png'
Image = mpimg.imread(reconsPath)
plt.imshow(Image) # 显示图片
plt.axis('off') # 不显示坐标轴
plt.show()

# %%
genPath = './ave_samples/sampled-30.png'
Image = mpimg.imread(genPath)
plt.imshow(Image) # 显示图片
plt.axis('off') # 不显示坐标轴
plt.show()
